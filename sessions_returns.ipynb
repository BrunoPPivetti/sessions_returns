# %%
import pandas as pd 
import numpy as np
from zoneinfo import ZoneInfo

# %%
eurusd = pd.read_csv('EURUSD_H1.csv', sep='\t', usecols=['<DATE>','<TIME>','<OPEN>','<CLOSE>','<HIGH>','<LOW>'])
gbpusd = pd.read_csv('GBPUSD_H1.csv', sep='\t', usecols=['<DATE>','<TIME>','<OPEN>','<CLOSE>','<HIGH>','<LOW>'])
usdjpy = pd.read_csv('USDJPY_H1.csv', sep='\t', usecols=['<DATE>','<TIME>','<OPEN>','<CLOSE>','<HIGH>','<LOW>'])
nq = pd.read_csv('US100.cash_H1.csv', sep='\t', usecols=['<DATE>','<TIME>','<OPEN>','<CLOSE>','<HIGH>','<LOW>'])
dax = pd.read_csv('GER40.cash_H1.csv', sep='\t', usecols=['<DATE>','<TIME>','<OPEN>','<CLOSE>','<HIGH>','<LOW>'])
xauusd = pd.read_csv('XAUUSD_H1.csv', sep='\t', usecols=['<DATE>','<TIME>','<OPEN>','<CLOSE>','<HIGH>','<LOW>'])

# %%
eurusd['DATE'] = pd.to_datetime(eurusd['<DATE>'] + ' ' + eurusd['<TIME>'])
gbpusd['DATE'] = pd.to_datetime(gbpusd['<DATE>'] + ' ' + gbpusd['<TIME>'])
usdjpy['DATE'] = pd.to_datetime(usdjpy['<DATE>'] + ' ' + usdjpy['<TIME>'])
nq['DATE'] = pd.to_datetime(nq['<DATE>'] + ' ' + nq['<TIME>'])
dax['DATE'] = pd.to_datetime(dax['<DATE>'] + ' ' + dax['<TIME>'])
xauusd['DATE'] = pd.to_datetime(xauusd['<DATE>'] + ' ' + xauusd['<TIME>'])

# %%
eurusd.set_index('DATE',inplace=True)
eurusd = eurusd.drop(['<DATE>','<TIME>'], axis=1)

gbpusd.set_index('DATE',inplace=True)
gbpusd = gbpusd.drop(['<DATE>','<TIME>'], axis=1)

usdjpy.set_index('DATE',inplace=True)
usdjpy = usdjpy.drop(['<DATE>','<TIME>'], axis=1)

nq.set_index('DATE',inplace=True)
nq = nq.drop(['<DATE>','<TIME>'], axis=1)

dax.set_index('DATE',inplace=True)
dax = dax.drop(['<DATE>','<TIME>'], axis=1)

xauusd.set_index('DATE',inplace=True)
xauusd = xauusd.drop(['<DATE>','<TIME>'], axis=1)

# %%
#fuso horário UTC+3
eurusd.index = eurusd.index.tz_localize('Etc/GMT-3')
eurusd.index = eurusd.index.tz_convert('UTC')

gbpusd.index = gbpusd.index.tz_localize('Etc/GMT-3')
gbpusd.index = gbpusd.index.tz_convert('UTC')

usdjpy.index = usdjpy.index.tz_localize('Etc/GMT-3')
usdjpy.index = usdjpy.index.tz_convert('UTC')

nq.index = nq.index.tz_localize('Etc/GMT-3')
nq.index = nq.index.tz_convert('UTC')

dax.index = dax.index.tz_localize('Etc/GMT-3')
dax.index = dax.index.tz_convert('UTC')

xauusd.index = xauusd.index.tz_localize('Etc/GMT-3')
xauusd.index = xauusd.index.tz_convert('UTC')

# %%
eurusd_asia = eurusd.copy()
eurusd_asia.index = eurusd_asia.index.tz_convert('Asia/Tokyo')
eurusd_asia = eurusd_asia.between_time('09:00','15:00')

eurusd_london = eurusd.copy()
eurusd_london.index = eurusd_london.index.tz_convert('Europe/London')
eurusd_london = eurusd_london.between_time('08:00','16:30')

eurusd_ny = eurusd.copy()
eurusd_ny.index = eurusd_ny.index.tz_convert('America/New_York')
eurusd_ny = eurusd_ny.between_time('09:30','16:00')
#================================================
gbpusd_asia = gbpusd.copy()
gbpusd_asia.index = gbpusd_asia.index.tz_convert('Asia/Tokyo')
gbpusd_asia = gbpusd_asia.between_time('09:00','15:00')

gbpusd_london = gbpusd.copy()
gbpusd_london.index = gbpusd_london.index.tz_convert('Europe/London')
gbpusd_london = gbpusd_london.between_time('08:00','16:30')

gbpusd_ny = gbpusd.copy()
gbpusd_ny.index = gbpusd_ny.index.tz_convert('America/New_York')
gbpusd_ny = gbpusd_ny.between_time('09:30','16:00')
#================================================
usdjpy_asia = usdjpy.copy()
usdjpy_asia.index = usdjpy_asia.index.tz_convert('Asia/Tokyo')
usdjpy_asia = usdjpy_asia.between_time('09:00','15:00')

usdjpy_london = usdjpy.copy()
usdjpy_london.index = usdjpy_london.index.tz_convert('Europe/London')
usdjpy_london = usdjpy_london.between_time('08:00','16:30')

usdjpy_ny = usdjpy.copy()
usdjpy_ny.index = usdjpy_ny.index.tz_convert('America/New_York')
usdjpy_ny = usdjpy_ny.between_time('09:30','16:00')
#================================================
nq_asia = nq.copy()
nq_asia.index = nq_asia.index.tz_convert('Asia/Tokyo')
nq_asia = nq_asia.between_time('09:00','15:00')

nq_london = nq.copy()
nq_london.index = nq_london.index.tz_convert('Europe/London')
nq_london = nq_london.between_time('08:00','16:30')

nq_ny = nq.copy()
nq_ny.index = nq_ny.index.tz_convert('America/New_York')
nq_ny = nq_ny.between_time('09:30','16:00')
#================================================
dax_asia = dax.copy()
dax_asia.index = dax_asia.index.tz_convert('Asia/Tokyo')
dax_asia = dax_asia.between_time('09:00','15:00')

dax_london = dax.copy()
dax_london.index = dax_london.index.tz_convert('Europe/London')
dax_london = dax_london.between_time('08:00','16:30')

dax_ny = dax.copy()
dax_ny.index = dax_ny.index.tz_convert('America/New_York')
dax_ny = dax_ny.between_time('09:30','16:00')
#================================================
xauusd_asia = xauusd.copy()
xauusd_asia.index = xauusd_asia.index.tz_convert('Asia/Tokyo')
xauusd_asia = xauusd_asia.between_time('09:00','15:00')

xauusd_london = xauusd.copy()
xauusd_london.index = xauusd_london.index.tz_convert('Europe/London')
xauusd_london = xauusd_london.between_time('08:00','16:30')

xauusd_ny = xauusd.copy()
xauusd_ny.index = xauusd_ny.index.tz_convert('America/New_York')
xauusd_ny = xauusd_ny.between_time('09:30','16:00')

# %%
eurusd_return_asia = eurusd_asia['<CLOSE>'].resample('D').apply(
    lambda x: (x.iloc[-1] - x.iloc[0])/x.iloc[-1] if len(x) > 0 else None
)

eurusd_return_london = eurusd_london['<CLOSE>'].resample('D').apply(
    lambda x: (x.iloc[-1] - x.iloc[0])/x.iloc[-1] if len(x) > 0 else None
)

eurusd_return_ny = eurusd_ny['<CLOSE>'].resample('D').apply(
    lambda x: (x.iloc[-1] - x.iloc[0])/x.iloc[-1] if len(x) > 0 else None
)
#==========================================================================
gbpusd_return_asia = gbpusd_asia['<CLOSE>'].resample('D').apply(
    lambda x: (x.iloc[-1] - x.iloc[0])/x.iloc[-1] if len(x) > 0 else None
)

gbpusd_return_london = gbpusd_london['<CLOSE>'].resample('D').apply(
    lambda x: (x.iloc[-1] - x.iloc[0])/x.iloc[-1] if len(x) > 0 else None
)

gbpusd_return_ny = gbpusd_ny['<CLOSE>'].resample('D').apply(
    lambda x: (x.iloc[-1] - x.iloc[0])/x.iloc[-1] if len(x) > 0 else None
)
#=========================================================================
usdjpy_return_asia = usdjpy_asia['<CLOSE>'].resample('D').apply(
    lambda x: (x.iloc[-1] - x.iloc[0])/x.iloc[-1] if len(x) > 0 else None
)

usdjpy_return_london = usdjpy_london['<CLOSE>'].resample('D').apply(
    lambda x: (x.iloc[-1] - x.iloc[0])/x.iloc[-1] if len(x) > 0 else None
)

usdjpy_return_ny = usdjpy_ny['<CLOSE>'].resample('D').apply(
    lambda x: (x.iloc[-1] - x.iloc[0])/x.iloc[-1] if len(x) > 0 else None
)
#=========================================================================
nq_return_asia = nq_asia['<CLOSE>'].resample('D').apply(
    lambda x: (x.iloc[-1] - x.iloc[0])/x.iloc[-1] if len(x) > 0 else None
)

nq_return_london = nq_london['<CLOSE>'].resample('D').apply(
    lambda x: (x.iloc[-1] - x.iloc[0])/x.iloc[-1] if len(x) > 0 else None
)

nq_return_ny = nq_ny['<CLOSE>'].resample('D').apply(
    lambda x: (x.iloc[-1] - x.iloc[0])/x.iloc[-1] if len(x) > 0 else None
)
#==========================================================================
dax_return_asia = dax_asia['<CLOSE>'].resample('D').apply(
    lambda x: (x.iloc[-1] - x.iloc[0])/x.iloc[-1] if len(x) > 0 else None
)

dax_return_london = dax_london['<CLOSE>'].resample('D').apply(
    lambda x: (x.iloc[-1] - x.iloc[0])/x.iloc[-1] if len(x) > 0 else None
)

dax_return_ny = dax_ny['<CLOSE>'].resample('D').apply(
    lambda x: (x.iloc[-1] - x.iloc[0])/x.iloc[-1] if len(x) > 0 else None
)
#=========================================================================
xauusd_return_asia = xauusd_asia['<CLOSE>'].resample('D').apply(
    lambda x: (x.iloc[-1] - x.iloc[0])/x.iloc[-1] if len(x) > 0 else None
)

xauusd_return_london = xauusd_london['<CLOSE>'].resample('D').apply(
    lambda x: (x.iloc[-1] - x.iloc[0])/x.iloc[-1] if len(x) > 0 else None
)

xauusd_return_ny = xauusd_ny['<CLOSE>'].resample('D').apply(
    lambda x: (x.iloc[-1] - x.iloc[0])/x.iloc[-1] if len(x) > 0 else None
)
